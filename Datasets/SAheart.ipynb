# %%
#importing modules
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df=pd.read_csv("https://hastie.su.domains/ElemStatLearn/datasets/SAheart.data")

# %%
df
# Out:
#      row.names  sbp  tobacco    ldl  adiposity  famhist  typea  obesity  \
# 0            1  160    12.00   5.73      23.11  Present     49    25.30
# 1            2  144     0.01   4.41      28.61   Absent     55    28.87
# 2            3  118     0.08   3.48      32.28  Present     52    29.14
# 3            4  170     7.50   6.41      38.03  Present     51    31.99
# 4            5  134    13.60   3.50      27.78  Present     60    25.99
# ..         ...  ...      ...    ...        ...      ...    ...      ...
# 457        459  214     0.40   5.98      31.72   Absent     64    28.45
# 458        460  182     4.20   4.41      32.10   Absent     52    28.61
# 459        461  108     3.00   1.59      15.23   Absent     40    20.09
# 460        462  118     5.40  11.61      30.79   Absent     64    27.35
# 461        463  132     0.00   4.82      33.41  Present     62    14.70
#
#      alcohol  age  chd
# 0      97.20   52    1
# 1       2.06   63    1
# 2       3.81   46    0
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 462 entries, 0 to 461
# Data columns (total 11 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   row.names  462 non-null    int64
#  1   sbp        462 non-null    int64
#  2   tobacco    462 non-null    float64
#  3   ldl        462 non-null    float64
#  4   adiposity  462 non-null    float64
#  5   famhist    462 non-null    object
#  6   typea      462 non-null    int64
#  7   obesity    462 non-null    float64
#  8   alcohol    462 non-null    float64
#  9   age        462 non-null    int64
#  10  chd        462 non-null    int64
# dtypes: float64(5), int64(5), object(1)
# memory usage: 39.8+ KB

# %%
df[df["famhist"]=="Present"]
# Out:
#      row.names  sbp  tobacco   ldl  adiposity  famhist  typea  obesity  \
# 0            1  160    12.00  5.73      23.11  Present     49    25.30
# 2            3  118     0.08  3.48      32.28  Present     52    29.14
# 3            4  170     7.50  6.41      38.03  Present     51    31.99
# 4            5  134    13.60  3.50      27.78  Present     60    25.99
# 5            6  132     6.20  6.47      36.21  Present     62    30.77
# ..         ...  ...      ...   ...        ...      ...    ...      ...
# 449        451  144     4.00  5.03      25.78  Present     57    27.55
# 452        454  154     5.53  3.20      28.81  Present     61    26.15
# 453        455  124     1.60  7.22      39.68  Present     36    31.50
# 456        458  170     0.40  4.11      42.06  Present     56    33.10
# 461        463  132     0.00  4.82      33.41  Present     62    14.70
#
#      alcohol  age  chd
# 0      97.20   52    1
# 2       3.81   46    0
# 3      24.26   58    1
# ...

# %%
df.shape
# Out:
# (462, 11)

# %%
df[df["famhist"]=="Present"].query('age < 50')
# Out:
#      row.names  sbp  tobacco   ldl  adiposity  famhist  typea  obesity  \
# 2            3  118     0.08  3.48      32.28  Present     52    29.14
# 4            5  134    13.60  3.50      27.78  Present     60    25.99
# 5            6  132     6.20  6.47      36.21  Present     62    30.77
# 8            9  114     0.00  3.83      19.40  Present     49    24.86
# 11          12  134    14.10  4.44      22.39  Present     65    23.09
# ..         ...  ...      ...   ...        ...      ...    ...      ...
# 447        449  130     0.00  1.88      12.51  Present     52    20.28
# 448        450  124     1.80  3.74      16.64  Present     42    22.26
# 449        451  144     4.00  5.03      25.78  Present     57    27.55
# 452        454  154     5.53  3.20      28.81  Present     61    26.15
# 461        463  132     0.00  4.82      33.41  Present     62    14.70
#
#      alcohol  age  chd
# 2       3.81   46    0
# 4      57.34   49    1
# 5      14.14   45    0
# ...

# %%
df.isnull().sum()  # finding null(missing) value
# Out:
# row.names    0
# sbp          0
# tobacco      0
# ldl          0
# adiposity    0
# famhist      0
# typea        0
# obesity      0
# alcohol      0
# age          0
# chd          0
# dtype: int64

# %%
df.nlargest(1,"age")
# Out:
#     row.names  sbp  tobacco   ldl  adiposity famhist  typea  obesity  alcohol  \
# 91         92  120      3.7  4.02      39.66  Absent     61    30.57      0.0
#
#     age  chd
# 91   64    1

# %%
plt.figure(figsize=(12,8))
sns.regplot(data=df[df["famhist"]=="Present"],x="age",y="tobacco")
plt.title("Correlation Between Age and Tobacco where famhist are present")
# Out:
# Text(0.5, 1.0, 'Correlation Between Age and Tobacco where famhist are present')

# %%
sns.boxplot(data=df,x="sbp")
# Out:
# <AxesSubplot: xlabel='sbp'>

# %% [markdown]
# # How many records are present in the dataset? Print the metadata information of the dataset

# %%
df
# Out:
#      row.names  sbp  tobacco    ldl  adiposity  famhist  typea  obesity  \
# 0            1  160    12.00   5.73      23.11  Present     49    25.30
# 1            2  144     0.01   4.41      28.61   Absent     55    28.87
# 2            3  118     0.08   3.48      32.28  Present     52    29.14
# 3            4  170     7.50   6.41      38.03  Present     51    31.99
# 4            5  134    13.60   3.50      27.78  Present     60    25.99
# ..         ...  ...      ...    ...        ...      ...    ...      ...
# 457        459  214     0.40   5.98      31.72   Absent     64    28.45
# 458        460  182     4.20   4.41      32.10   Absent     52    28.61
# 459        461  108     3.00   1.59      15.23   Absent     40    20.09
# 460        462  118     5.40  11.61      30.79   Absent     64    27.35
# 461        463  132     0.00   4.82      33.41  Present     62    14.70
#
#      alcohol  age  chd
# 0      97.20   52    1
# 1       2.06   63    1
# 2       3.81   46    0
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 462 entries, 0 to 461
# Data columns (total 11 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   row.names  462 non-null    int64
#  1   sbp        462 non-null    int64
#  2   tobacco    462 non-null    float64
#  3   ldl        462 non-null    float64
#  4   adiposity  462 non-null    float64
#  5   famhist    462 non-null    object
#  6   typea      462 non-null    int64
#  7   obesity    462 non-null    float64
#  8   alcohol    462 non-null    float64
#  9   age        462 non-null    int64
#  10  chd        462 non-null    int64
# dtypes: float64(5), int64(5), object(1)
# memory usage: 39.8+ KB

# %%
df.shape
# Out:
# (462, 11)

# %% [markdown]
# # Draw a plot to show the number of persons having CHD or not in comparison to those having family history of the disease or not.

# %%
sns.countplot(data=df,x="chd",hue="famhist")
# Out:
# <AxesSubplot: xlabel='chd', ylabel='count'>

# %% [markdown]
# #  Does age have any correlation with sbp? Choose appropriate plot to show the relationship

# %%
sns.regplot(data=df,x="age",y="sbp")
# Out:
# <AxesSubplot: xlabel='age', ylabel='sbp'>

# %% [markdown]
# # Compare the distribution of tobacco consumption for persons having CHD and not having CHD

# %%
dff=df[df["chd"]==1]
dff
# Out:
#      row.names  sbp  tobacco   ldl  adiposity  famhist  typea  obesity  \
# 0            1  160    12.00  5.73      23.11  Present     49    25.30
# 1            2  144     0.01  4.41      28.61   Absent     55    28.87
# 3            4  170     7.50  6.41      38.03  Present     51    31.99
# 4            5  134    13.60  3.50      27.78  Present     60    25.99
# 7            8  114     4.08  4.59      14.60  Present     62    23.11
# ..         ...  ...      ...   ...        ...      ...    ...      ...
# 453        455  124     1.60  7.22      39.68  Present     36    31.50
# 454        456  146     0.64  4.82      28.02   Absent     60    28.11
# 455        457  128     2.24  2.83      26.48   Absent     48    23.96
# 458        460  182     4.20  4.41      32.10   Absent     52    28.61
# 461        463  132     0.00  4.82      33.41  Present     62    14.70
#
#      alcohol  age  chd
# 0      97.20   52    1
# 1       2.06   63    1
# 3      24.26   58    1
# ...

# %%
dff2=df[df["chd"]==0]
dff2
# Out:
#      row.names  sbp  tobacco    ldl  adiposity  famhist  typea  obesity  \
# 2            3  118     0.08   3.48      32.28  Present     52    29.14
# 5            6  132     6.20   6.47      36.21  Present     62    30.77
# 6            7  142     4.05   3.38      16.20   Absent     59    20.81
# 8            9  114     0.00   3.83      19.40  Present     49    24.86
# 12          13  118     0.00   1.88      10.05   Absent     59    21.57
# ..         ...  ...      ...    ...        ...      ...    ...      ...
# 452        454  154     5.53   3.20      28.81  Present     61    26.15
# 456        458  170     0.40   4.11      42.06  Present     56    33.10
# 457        459  214     0.40   5.98      31.72   Absent     64    28.45
# 459        461  108     3.00   1.59      15.23   Absent     40    20.09
# 460        462  118     5.40  11.61      30.79   Absent     64    27.35
#
#      alcohol  age  chd
# 2       3.81   46    0
# 5      14.14   45    0
# 6       2.62   38    0
# ...

# %%
dff=df[df["chd"]==1]
dff2=df[df["chd"]==0]


fig=plt.figure(figsize=(8,6))
axes= fig.add_subplot(1,1,1)

axes.hist([dff["tobacco"],dff2["tobacco"]],color=["blue","green"],label=["having chd","not having chd"])
# Out:
# (array([[ 68.,  37.,  26.,  14.,   8.,   1.,   3.,   0.,   2.,   1.],
#         [205.,  61.,  19.,   8.,   5.,   2.,   2.,   0.,   0.,   0.]]),
#  array([ 0.  ,  3.12,  6.24,  9.36, 12.48, 15.6 , 18.72, 21.84, 24.96,
#         28.08, 31.2 ]),
#  <a list of 2 BarContainer objects>)

# %%
dff=df[df["chd"]==1]
dff2=df[df["chd"]==0]
fig=plt.figure(figsize=(8,6))
axes=fig.add_subplot(1,1,1)
axes.hist([dff["tobacco"],dff2["tobacco"]],color=["darkcyan","darkslategrey"],label=["persons having CHD","persons not having CHD"],bins=5)
axes.set_title("distribution of tobacco consumption for persons having CHD and not having CHD. ")
axes.legend()

# %%
sns.displot(data=df,x="tobacco",hue="chd",kde=True)

# %%
sns.boxplot(data=df,x="chd",y="tobacco")
# Out:
# <AxesSubplot: xlabel='chd', ylabel='tobacco'>

# %% [markdown]
# #  Derive a new column called agegroup from age column where persons falling in different age ranges are categorized as below

# %%
df["age"].min()
df
# Out:
#      row.names  sbp  tobacco    ldl  adiposity  famhist  typea  obesity  \
# 0            1  160    12.00   5.73      23.11  Present     49    25.30
# 1            2  144     0.01   4.41      28.61   Absent     55    28.87
# 2            3  118     0.08   3.48      32.28  Present     52    29.14
# 3            4  170     7.50   6.41      38.03  Present     51    31.99
# 4            5  134    13.60   3.50      27.78  Present     60    25.99
# ..         ...  ...      ...    ...        ...      ...    ...      ...
# 457        459  214     0.40   5.98      31.72   Absent     64    28.45
# 458        460  182     4.20   4.41      32.10   Absent     52    28.61
# 459        461  108     3.00   1.59      15.23   Absent     40    20.09
# 460        462  118     5.40  11.61      30.79   Absent     64    27.35
# 461        463  132     0.00   4.82      33.41  Present     62    14.70
#
#      alcohol  age  chd
# 0      97.20   52    1
# 1       2.06   63    1
# 2       3.81   46    0
# ...

# %%
df["age"].max()
# Out:
# 64

# %%
def age_colum(age):
    if age<=15 :
        return "child"
    elif 15<age<=35 :
        return "young"
    elif 35<age<55 :
        return "middle age "
    else :
        return "old"

# %%
df["agegroup"]=df["age"].apply(age_colum)
df["agegroup"].unique()
# Out:
# array(['middle age ', 'old', 'young', 'child'], dtype=object)

# %%
df
# Out:
#      row.names  sbp  tobacco    ldl  adiposity  famhist  typea  obesity  \
# 0            1  160    12.00   5.73      23.11  Present     49    25.30
# 1            2  144     0.01   4.41      28.61   Absent     55    28.87
# 2            3  118     0.08   3.48      32.28  Present     52    29.14
# 3            4  170     7.50   6.41      38.03  Present     51    31.99
# 4            5  134    13.60   3.50      27.78  Present     60    25.99
# ..         ...  ...      ...    ...        ...      ...    ...      ...
# 457        459  214     0.40   5.98      31.72   Absent     64    28.45
# 458        460  182     4.20   4.41      32.10   Absent     52    28.61
# 459        461  108     3.00   1.59      15.23   Absent     40    20.09
# 460        462  118     5.40  11.61      30.79   Absent     64    27.35
# 461        463  132     0.00   4.82      33.41  Present     62    14.70
#
#      alcohol  age  chd     agegroup
# 0      97.20   52    1  middle age
# ...

# %% [markdown]
# #  Draw a box plot to compare distributions of ldl for different age groups

# %%
sns.boxplot(data=df,y="ldl",x="agegroup",hue="chd")
# Out:
# <AxesSubplot: xlabel='agegroup', ylabel='ldl'>

# %%
sns.boxplot(data=df)
# Out:
# C:\Users\owais\AppData\Local\Programs\Python\Python310\lib\site-packages\seaborn\categorical.py:470: FutureWarning: iteritems is deprecated and will be removed in a future version. Use .items instead.
#   plot_data = [np.asarray(s, float) for k, s in iter_data]
# <AxesSubplot: >
